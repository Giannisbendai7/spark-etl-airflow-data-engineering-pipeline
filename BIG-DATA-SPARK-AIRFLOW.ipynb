# %%
pip install apache-airflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator
from datetime import datetime

def extract():
    print("Extract data from API")

def transform():
    print("Clean and transform data")

def load():
    print("Load into database")

with DAG(
    dag_id="simple_etl_pipeline",
    start_date=datetime(2024, 1, 1),
    schedule_interval="@daily",
    catchup=False
) as dag:

    t1 = PythonOperator(task_id="extract", python_callable=extract)
    t2 = PythonOperator(task_id="transform", python_callable=transform)
    t3 = PythonOperator(task_id="load", python_callable=load)

    t1 >> t2 >> t3
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\airflow\__init__.py:47: RuntimeWarning: Airflow currently can be run on POSIX-compliant Operating Systems. For development, it is regularly tested on fairly modern Linux Distros and recent versions of macOS. On Windows you can run it via WSL2 (Windows Subsystem for Linux 2) or via Linux Containers. The work to add Windows support is tracked via https://github.com/apache/airflow/issues/10388, but it is not a high priority.
#   warnings.warn(
# 2026-06-08T21:29:51.492567Z [warning  ] The `airflow.operators.python.PythonOperator` attribute is deprecated. Please use `'airflow.providers.standard.operators.python.PythonOperator'`. [py.warnings] category=DeprecatedImportWarning filename=C:\Users\user\AppData\Local\Temp\ipykernel_29060\4023180462.py lineno=2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 14
# ...

# %%
import airflow
print(airflow.__version__)
# Out:
# 3.2.2

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator
from datetime import datetime

def extract():
    print("Extract data")

def transform():
    print("Transform data")

def load():
    print("Load data")

with DAG(
    dag_id="simple_etl_pipeline",
    start_date=datetime(2024, 1, 1),
    schedule="@daily",
    catchup=False,
) as dag:

    t1 = PythonOperator(
        task_id="extract",
        python_callable=extract
    )

    t2 = PythonOperator(
        task_id="transform",
        python_callable=transform
    )

    t3 = PythonOperator(
        task_id="load",
        python_callable=load
    )

    t1 >> t2 >> t3
# Out:
# 2026-06-08T21:35:16.756903Z [warning  ] The `airflow.operators.python.PythonOperator` attribute is deprecated. Please use `'airflow.providers.standard.operators.python.PythonOperator'`. [py.warnings] category=DeprecatedImportWarning filename=C:\Users\user\AppData\Local\Temp\ipykernel_29060\4207570750.py lineno=2

# %%
def extract():
    data = [10, 20, 30, 40]
    print("Raw data:", data)
    return data

# %%
def transform():
    data = [10, 20, 30, 40]

    transformed = []

    for x in data:
        transformed.append(x * 2)

    print("Transformed:", transformed)

    return transformed

# %%
def load():
    transformed = [20, 40, 60, 80]

    print("Loading to database...")
    print(transformed)

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\user

# %%
import os

print(os.path.exists(r"C:\Users\user\Downloads\car_sales_data.csv.zip"))
# Out:
# True

# %%
spark.stop()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("test") \
    .master("local[*]") \
    .getOrCreate()

# %%
import os

print(os.path.exists(r"C:\Users\user\Downloads\car_sales_data.csv.zip"))
# Out:
# True

# %%
import zipfile

zip_path = r"C:\Users\user\Downloads\car_sales_data.csv.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    print(zip_ref.namelist())
# Out:
# ['car_sales_data.csv']

# %%
import zipfile

zip_path = r"C:\Users\user\Downloads\car_sales_data.csv.zip"

extract_path = r"C:\Users\user\Downloads\car_sales"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Done!")
# Out:
# Done!

# %%
spark.stop()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local[*]") \
    .appName("car_sales") \
    .getOrCreate()

# %%
df = spark.read.csv(
    r"C:\Users\user\Downloads\car_sales\car_sales_data.csv",
    header=True,
    inferSchema=True
)

df.show(5)
# Out:
# +----------+---------------+--------------+--------+---------+--------+----------+-------------------+-----------------+
# |      Date|    Salesperson| Customer Name|Car Make|Car Model|Car Year|Sale Price|    Commission Rate|Commission Earned|
# +----------+---------------+--------------+--------+---------+--------+----------+-------------------+-----------------+
# |2022-08-01|Monica Moore MD|   Mary Butler|  Nissan|   Altima|    2018|     15983|0.07049522770435404|          1126.73|
# |2023-03-15|   Roberto Rose|Richard Pierce|  Nissan|    F-150|    2016|     38474|0.13443883688865882|           5172.4|
# |2023-04-29|   Ashley Ramos|  Sandra Moore|    Ford|    Civic|    2016|     33340|0.11453592158660743|          3818.63|
# |2022-09-04| Patrick Harris|  Johnny Scott|    Ford|   Altima|    2013|     41937|0.09219072181202051|           3866.2|
# |2022-06-16|     Eric Lopez| Vanessa Jones|   Honda|Silverado|    2022|     20256|0.11348979252839732|          2298.85|
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Date: date (nullable = true)
#  |-- Salesperson: string (nullable = true)
#  |-- Customer Name: string (nullable = true)
#  |-- Car Make: string (nullable = true)
#  |-- Car Model: string (nullable = true)
#  |-- Car Year: integer (nullable = true)
#  |-- Sale Price: integer (nullable = true)
#  |-- Commission Rate: double (nullable = true)
#  |-- Commission Earned: double (nullable = true)

# %%
df.count()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# 2500000

# %%
import os

for root, dirs, files in os.walk(r"C:\Users\user\Downloads"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# C:\Users\user\Downloads\about_top_cryptocurrencies_1B_information (1).csv
# C:\Users\user\Downloads\about_top_cryptocurrencies_1B_information.csv
# C:\Users\user\Downloads\abudhabi_constructor_performance.csv
# C:\Users\user\Downloads\bank (1).csv
# C:\Users\user\Downloads\bank.csv
# C:\Users\user\Downloads\bf_info.csv
# C:\Users\user\Downloads\bitcoin_cash_price.csv
# C:\Users\user\Downloads\BTC-USD.csv
# C:\Users\user\Downloads\btcusd_1-min_data.csv
# C:\Users\user\Downloads\Business Funding Data.csv
# C:\Users\user\Downloads\candidates (1).csv
# C:\Users\user\Downloads\candidates.csv
# C:\Users\user\Downloads\Churn_Modelling.csv
# C:\Users\user\Downloads\CO2_Emissions_1960-2018.csv
# C:\Users\user\Downloads\column_2C_weka.csv
# C:\Users\user\Downloads\combats (1).csv
# C:\Users\user\Downloads\combats (2).csv
# C:\Users\user\Downloads\combats.csv
# C:\Users\user\Downloads\Country-data.csv
# C:\Users\user\Downloads\Country.csv
# C:\Users\user\Downloads\credit_customers.csv
# ...

# %%
import os

size = os.path.getsize(
    r"C:\Users\user\Downloads\car_sales\car_sales_data.csv"
)

print("MB:", round(size / (1024**2), 2))
# Out:
# MB: 223.29

# %%
import shutil

total, used, free = shutil.disk_usage("C:")

print("Free GB:", round(free / (1024**3), 2))
# Out:
# Free GB: 1.45

# %%
import shutil
print(round(shutil.disk_usage("C:").free / (1024**3), 2))
# Out:
# 26.89

# %%
spark.stop()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local[*]") \
    .appName("car_sales") \
    .getOrCreate()

# %%
df = spark.read.csv(
    r"C:\Users\user\Downloads\car_sales\car_sales_data.csv",
    header=True,
    inferSchema=True
)

df.show(5)
# Out:
# +----------+---------------+--------------+--------+---------+--------+----------+-------------------+-----------------+
# |      Date|    Salesperson| Customer Name|Car Make|Car Model|Car Year|Sale Price|    Commission Rate|Commission Earned|
# +----------+---------------+--------------+--------+---------+--------+----------+-------------------+-----------------+
# |2022-08-01|Monica Moore MD|   Mary Butler|  Nissan|   Altima|    2018|     15983|0.07049522770435404|          1126.73|
# |2023-03-15|   Roberto Rose|Richard Pierce|  Nissan|    F-150|    2016|     38474|0.13443883688865882|           5172.4|
# |2023-04-29|   Ashley Ramos|  Sandra Moore|    Ford|    Civic|    2016|     33340|0.11453592158660743|          3818.63|
# |2022-09-04| Patrick Harris|  Johnny Scott|    Ford|   Altima|    2013|     41937|0.09219072181202051|           3866.2|
# |2022-06-16|     Eric Lopez| Vanessa Jones|   Honda|Silverado|    2022|     20256|0.11348979252839732|          2298.85|
# ...

# %%
df.count()
# Out:
# 2500000

# %%
df.select("Car Make").distinct().show()
# Out:
# +---------+
# | Car Make|
# +---------+
# |Chevrolet|
# |    Honda|
# |   Toyota|
# |   Nissan|
# |     Ford|
# +---------+

# %%
df.groupBy("Car Make").count().show()
# Out:
# +---------+------+
# | Car Make| count|
# +---------+------+
# |Chevrolet|500455|
# |    Honda|500687|
# |   Toyota|500147|
# |   Nissan|498930|
# |     Ford|499781|
# +---------+------+

# %%
from pyspark.sql.functions import sum

df.groupBy("Car Make") \
  .agg(sum("Sale Price").alias("Revenue")) \
  .orderBy("Revenue", ascending=False) \
  .show()
# Out:
# +---------+-----------+
# | Car Make|    Revenue|
# +---------+-----------+
# |    Honda|15036898624|
# |Chevrolet|15021372800|
# |   Toyota|15005405240|
# |     Ford|14990661833|
# |   Nissan|14976108358|
# +---------+-----------+

# %%
from airflow import DAG
from airflow.operators.python import PythonOperator
from datetime import datetime

def etl():
    print("Run Spark ETL pipeline")2026-06-09T15:00:51.452594Z [warning  ] The `airflow.operators.python.PythonOperator` attribute is deprecated. Please use `'airflow.providers.standard.operators.python.PythonOperator'`. [py.warnings] category=DeprecatedImportWarning filename=C:\Users\user\AppData\Local\Temp\ipykernel_9784\422586910.py lineno=2


with DAG(
    dag_id="car_sales_pipeline",
    start_date=datetime(2024, 1, 1),
    schedule="@daily",
    catchup=False
) as dag:

    task1 = PythonOperator(
        task_id="run_etl",
        python_callable=etl
    )
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\airflow\__init__.py:47: RuntimeWarning: Airflow currently can be run on POSIX-compliant Operating Systems. For development, it is regularly tested on fairly modern Linux Distros and recent versions of macOS. On Windows you can run it via WSL2 (Windows Subsystem for Linux 2) or via Linux Containers. The work to add Windows support is tracked via https://github.com/apache/airflow/issues/10388, but it is not a high priority.
#   warnings.warn(
# 2026-06-09T15:00:51.452594Z [warning  ] The `airflow.operators.python.PythonOperator` attribute is deprecated. Please use `'airflow.providers.standard.operators.python.PythonOperator'`. [py.warnings] category=DeprecatedImportWarning filename=C:\Users\user\AppData\Local\Temp\ipykernel_9784\422586910.py lineno=2

# %%
from airflow import DAG
from airflow.providers.standard.operators.python import PythonOperator
from datetime import datetime

def etl():
    print("Run Spark ETL pipeline")

with DAG(
    dag_id="car_sales_pipeline",
    start_date=datetime(2024, 1, 1),
    schedule="@daily",
    catchup=False
) as dag:

    task1 = PythonOperator(
        task_id="run_etl",
        python_callable=etl
    )

# %%
def etl():
    print("Run Spark ETL pipeline")

etl()
# Out:
# Run Spark ETL pipeline
